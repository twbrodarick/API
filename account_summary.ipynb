# %%
import os
import plaid
import requests
import datetime
import json
import pandas as pd
# %matplotlib inline

# %%
def pretty_print_response(response):
  print(json.dumps(response, indent=4, sort_keys=True))

# %%
PLAID_CLIENT_ID = os.getenv('PLAID_CLIENT_ID')
PLAID_SECRET = os.getenv('PLAID_SBX_SECRET_KEY')
PLAID_PUBLIC_KEY = os.getenv('PLAID_PUBLIC_KEY')
PLAID_ENV = os.getenv('PLAID_ENV', 'sandbox')
PLAID_PRODUCTS = os.getenv('PLAID_PRODUCTS', 'transactions')

# %% [markdown]
# # Plaid Access Token
#
# In this section, you will use the plaid-python api to generate the correct authentication tokens to access data in the free developer Sandbox. This mimics how you might connect to your own account or a customer account, but due to privacy issues, this homework will only require connecting to and analyzing the fake data from the developer sandbox that Plaid provides.
#
# Complete the following steps to generate an access token:
# 1. Create a client to connect to plaid
# 2. Use the client to generate a public token and request the following items:
# ['transactions', 'income', 'assets']
# 3. Exchange the public token for an access token
# 4. Test the access token by requesting and printing the available test accounts

# %% [markdown]
# ### 1. Create a client to connect to plaid

# %%
INSTITUTION_ID = "ins_109508"

# %%
# YOUR CODE HERE
client = plaid.Client(client_id=PLAID_CLIENT_ID, public_key=PLAID_PUBLIC_KEY, secret=PLAID_SECRET, environment='sandbox')

# %% [markdown]
# ### 2. Generate a public token

# %%
# YOUR CODE HERE
create_token = client.Sandbox.public_token.create(INSTITUTION_ID, ['transactions','income','assets'])

# %% [markdown]
# ### 3. Exchange the public token for an access token

# %%
# YOUR CODE HERE
exchange_response = client.Item.public_token.exchange(create_token['public_token'])
access_token = exchange_response['access_token']

# %% [markdown]
# ### 4. Fetch Accounts

# %%
# YOUR CODE HERE
client.Accounts.get(access_token)
# Out:
# {'accounts': [{'account_id': 'dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE',
#    'balances': {'available': 100,
#     'current': 110,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '0000',
#    'name': 'Plaid Checking',
#    'official_name': 'Plaid Gold Standard 0% Interest Checking',
#    'subtype': 'checking',
#    'type': 'depository'},
#   {'account_id': 'aV4A78XXMzTNlGQ3oq7VHne5benR8yF7Qjexm',
#    'balances': {'available': 200,
#     'current': 210,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '1111',
#    'name': 'Plaid Saving',
#    'official_name': 'Plaid Silver Standard 0.1% Interest Saving',
#    'subtype': 'savings',
#    'type': 'depository'},
#   {'account_id': '48B4ZzbbK9IWGvrn7RlXI1ZRnZ1V7aHdA63wQ',
#    'balances': {'available': None,
#     'current': 1000,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '2222',
#    'name': 'Plaid CD',
#    'official_name': 'Plaid Bronze Standard 0.2% Interest CD',
#    'subtype': 'cd',
#    'type': 'depository'},
#   {'account_id': 'N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1',
#    'balances': {'available': None,
#     'current': 410,
#     'iso_currency_code': 'USD',
#     'limit': 2000,
#     'unofficial_currency_code': None},
#    'mask': '3333',
#    'name': 'Plaid Credit Card',
#    'official_name': 'Plaid Diamond 12.5% APR Interest Credit Card',
#    'subtype': 'credit card',
#    'type': 'credit'},
#   {'account_id': 'Pp947xWWq8IEeRo9XD7yUqAdVAqLjet7WxNrM',
#    'balances': {'available': 43200,
#     'current': 43200,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '4444',
#    'name': 'Plaid Money Market',
#    'official_name': 'Plaid Platinum Standard 1.85% Interest Money Market',
#    'subtype': 'money market',
#    'type': 'depository'},
#   {'account_id': 'jV1d7955AjTMdWGpN4XvhBlE3lBJPpC1LNG85',
#    'balances': {'available': None,
#     'current': 320.76,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '5555',
#    'name': 'Plaid IRA',
#    'official_name': None,
#    'subtype': 'ira',
#    'type': 'investment'},
#   {'account_id': '7AdjXxbbB6cQ5Jl9Rkr4Uogrvgo3RDfgnE1KZ',
#    'balances': {'available': None,
#     'current': 23631.9805,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '6666',
#    'name': 'Plaid 401k',
#    'official_name': None,
#    'subtype': '401k',
#    'type': 'investment'},
#   {'account_id': 'eV7rwGXXodT3nErvABmVIEy3jyEVDBFL5qVlb',
#    'balances': {'available': None,
#     'current': 65262,
#     'iso_currency_code': 'USD',
#     'limit': None,
#     'unofficial_currency_code': None},
#    'mask': '7777',
#    'name': 'Plaid Student Loan',
#    'official_name': None,
#    'subtype': 'student',
#    'type': 'loan'}],
#  'item': {'available_products': ['auth',
#    'balance',
#    'credit_details',
#    'identity',
#    'investments',
#    'liabilities'],
#   'billed_products': ['assets', 'income', 'transactions'],
#   'consent_expiration_time': None,
#   'error': None,
#   'institution_id': 'ins_109508',
#   'item_id': 'ylvgrXKKjGU6WKGyDNowHy4zMMQdDzCyPNqz9',
#   'webhook': ''},
#  'request_id': 'RPvXVGb8Of4SNmb'}

# %% [markdown]
# ---

# %% [markdown]
# # Account Transactions with Plaid
#
# In this section, you will use the Plaid Python SDK to connect to the Developer Sandbox account and grab a list of transactions. You will need to complete the following steps:
#
#
# 1. Use the access token to fetch the transactions for the last 90 days
# 2. Print the categories for each transaction type
# 3. Create a new DataFrame using the following fields from the JSON transaction data: `date, name, amount, category`. (For categories with more than one label, just use the first category label in the list)
# 4. Convert the data types to the appropriate types (i.e. datetimeindex for the date and float for the amount)

# %% [markdown]
# ### 1. Fetch the Transactions for the last 90 days

# %%
# YOUR CODE HERE
start_date = '{:%Y-%m-%d}'.format(datetime.datetime.now() + datetime.timedelta(-90))
end_date = '{:%Y-%m-%d}'.format(datetime.datetime.now())

transactions_response = client.Transactions.get(access_token,start_date,end_date)

transactions_fetch = json.dumps(transactions_response['transactions'],indent=4, sort_keys=True)

print(transactions_fetch)
# Out:
# [
#     {
#         "account_id": "aV4A78XXMzTNlGQ3oq7VHne5benR8yF7Qjexm",
#         "account_owner": null,
#         "amount": 25,
#         "authorized_date": null,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2020-04-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "8Ga7Zdmm3lCVZDv8MKzNsR7J3JpaWQiwLQ65E",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 5.4,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-04-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "MMbxPz44ApIJk87MZARwS6Px5xQLNBi9PAvk7",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "Pp947xWWq8IEeRo9XD7yUqAdVAqLjet7WxNrM",
#         "account_owner": null,
#         "amount": 5850,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2020-04-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "9n4e6a77xqs8RKkyGrBPiWry3yvJbQSRQe1M5",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "48B4ZzbbK9IWGvrn7RlXI1ZRnZ1V7aHdA63wQ",
#         "account_owner": null,
#         "amount": 1000,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2020-04-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "WGlZk7MMdmCzJpBabowXUpxAQAlR56tl1N8xd",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 78.5,
#         "authorized_date": null,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2020-04-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "A3MgKZVVeafwEBy3mNjlU1owkwVM6qi1AVDMn",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": -500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-04-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "1pKxWqVVGbIglxrJvRAzTDbjPjR8Bqi5eyRV3",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 12,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-04-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "LZn3PraaWLTgZ7ymwkoGTDw8m8lXPViPp4MBq",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 4.33,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2020-04-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "pVE7AyDDz1TJb5GW4Ka8SQPZ3Zgjm1TLV6GeX",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 89.4,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-04-11",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "oV8jyGDDrMT5LNj64qW8H4Rd7dgK1atR7BDAA",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "aV4A78XXMzTNlGQ3oq7VHne5benR8yF7Qjexm",
#         "account_owner": null,
#         "amount": -4.22,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2020-04-10",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "E4oA3pKK1jTgJ6bmLDraTK3BMBEXe6UXkA7zv",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-03-31",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "GP8qdgzzpeH6aAXP8L3dHNEaLav9mxC1PNvwD",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 6.33,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-03-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "gVQB7GXX84TqGoBPd5JVHlaoKozw6DtgnZB9d",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-03-26",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "nVgPAGDDKZT1WpPDQlwvHa5jrjgVy4t6W7RDx",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 2078.5,
#         "authorized_date": null,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2020-03-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "ylvgrXKKjGU6WKGyDNowHy4z9zqNE8SyX1mpx",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-03-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "mVoNAGDDqQTLVWNM4RgvidrDQDxpb4iLdKN8x",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2020-03-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "bVNlyGXX1BToWqlerKDVUqaZvZJE8yhVZ9jrW",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "aV4A78XXMzTNlGQ3oq7VHne5benR8yF7Qjexm",
#         "account_owner": null,
#         "amount": 25,
#         "authorized_date": null,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2020-03-16",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "rVAQwGDD3pT9ygQNXzwVs6KRJwxkDBCl6rDx8",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 5.4,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-03-16",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "k5LaA6DDG7ImGa9QLNyvH8X5ArmRkMuWd48VR",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "Pp947xWWq8IEeRo9XD7yUqAdVAqLjet7WxNrM",
#         "account_owner": null,
#         "amount": 5850,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2020-03-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "GP8qdgzzpeH6aAXP8L3dHNEBDn41kxu1PVnv7",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "48B4ZzbbK9IWGvrn7RlXI1ZRnZ1V7aHdA63wQ",
#         "account_owner": null,
#         "amount": 1000,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2020-03-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "Pp947xWWq8IEeRo9XD7yUqAk5KDorMS7WxN1a",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 78.5,
#         "authorized_date": null,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2020-03-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "zqR8zGrr7kSDz68pgPKQsk4GlVqwyDhoLAgal",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": -500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-03-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "JeAzVqxx8MU68Jde1oGyHWn4L7XKRahdgl5rw",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 12,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-03-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "wVypqGllNWTRxqpEbaevFed53GPRoLfro4l7Q",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 4.33,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2020-03-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "5E3N5BbbrvHVJGwbXvqdsLnkQPZprguZ7apPJ",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 89.4,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-03-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "VAVQqjLLxbcawrLd6WlqUx5m8wJyNRtWPjn8o",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "aV4A78XXMzTNlGQ3oq7VHne5benR8yF7Qjexm",
#         "account_owner": null,
#         "amount": -4.22,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2020-03-11",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "KQGBPKddE1SkvKaQ7D4VTmgZ5roJnXiVAlmP4",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-03-01",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "rVAQwGDD3pT9ygQNXzwVs6KRJwxkDBCl6rDwl",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 6.33,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-02-28",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "DapWBLqqMPCdXGDm7LQ4inkwDajqd8CvaAXPn",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-02-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "KQGBPKddE1SkvKaQ7D4VTmgZ5roJnXiVAlm86",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 2078.5,
#         "authorized_date": null,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2020-02-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "qVWeAGDDBLTbXmeajr1vfA9KplbR7LUd7eVW8",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-02-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "lVp4AGDDleTqx14ARPX8HbW3mkq9J7FZdKrWz",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2020-02-24",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "k5LaA6DDG7ImGa9QLNyvH8X5ArmRkMuWd48E3",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "aV4A78XXMzTNlGQ3oq7VHne5benR8yF7Qjexm",
#         "account_owner": null,
#         "amount": 25,
#         "authorized_date": null,
#         "category": [
#             "Payment",
#             "Credit Card"
#         ],
#         "category_id": "16001000",
#         "date": "2020-02-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CREDIT CARD 3333 PAYMENT *//",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "qVWeAGDDBLTbXmeajr1vfA9KplbR7LUd7eVae",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 5.4,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-02-15",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "XnqMreGGaysQVoj4Pg1GUnRWJVq7K5Cdn7xWx",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "Pp947xWWq8IEeRo9XD7yUqAdVAqLjet7WxNrM",
#         "account_owner": null,
#         "amount": 5850,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Debit"
#         ],
#         "category_id": "21006000",
#         "date": "2020-02-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "ACH Electronic CreditGUSTO PAY 123456",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": "ACH",
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "A3MgKZVVeafwEBy3mNjlU1onKxDGdqC1AboD5",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "48B4ZzbbK9IWGvrn7RlXI1ZRnZ1V7aHdA63wQ",
#         "account_owner": null,
#         "amount": 1000,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Deposit"
#         ],
#         "category_id": "21007000",
#         "date": "2020-02-14",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "CD DEPOSIT .INITIAL.",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "N1mdPBNNGotBndelVDqbuK8j5nJAgWCW5l73Z",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 78.5,
#         "authorized_date": null,
#         "category": [
#             "Recreation",
#             "Gyms and Fitness Centers"
#         ],
#         "category_id": "17018000",
#         "date": "2020-02-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Touchstone Climbing",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "JeAzVqxx8MU68Jde1oGyHWn4L7XKRahdgl5jP",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": -500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-02-13",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "6WxPv366zRuJXgekRoKaSp15loyrQ3cgXExob",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 12,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-02-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": "3322"
#         },
#         "name": "McDonald's",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "vVmLlwDD4ETlAWmprd8vt6gQ3yoB8JCWkLX3q",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 4.33,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Coffee Shop"
#         ],
#         "category_id": "13005043",
#         "date": "2020-02-12",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Starbucks",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "RgkPGaMMrWiV8XBze1MosXKlm8wLGMtRb6GvP",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 89.4,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-02-11",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "SparkFun",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "9n4e6a77xqs8RKkyGrBPiWr8NBZMXQhRQ7EWR",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "aV4A78XXMzTNlGQ3oq7VHne5benR8yF7Qjexm",
#         "account_owner": null,
#         "amount": -4.22,
#         "authorized_date": null,
#         "category": [
#             "Transfer",
#             "Credit"
#         ],
#         "category_id": "21005000",
#         "date": "2020-02-10",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "INTRST PYMNT",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "lVp4AGDDleTqx14ARPX8HbW3mkq9J7FZdKryG",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Airlines and Aviation Services"
#         ],
#         "category_id": "22001000",
#         "date": "2020-01-31",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "United Airlines",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "5E3N5BbbrvHVJGwbXvqdsLnkQPZprguZ7apVl",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "dVjKZkXXpxT6EBGabzRVHn8Ma8nzyxFZQ86xE",
#         "account_owner": null,
#         "amount": 6.33,
#         "authorized_date": null,
#         "category": [
#             "Travel",
#             "Taxi"
#         ],
#         "category_id": "22016000",
#         "date": "2020-01-29",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Uber",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "ylvgrXKKjGU6WKGyDNowHy4wrBMmj8iyXJDqr",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants"
#         ],
#         "category_id": "13005000",
#         "date": "2020-01-26",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Tectra Inc",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "wVypqGllNWTRxqpEbaevFed53GPRoLfro4l99",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 2078.5,
#         "authorized_date": null,
#         "category": [
#             "Payment"
#         ],
#         "category_id": "16000000",
#         "date": "2020-01-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "AUTOMATIC PAYMENT - THANK",
#         "payment_channel": "other",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "VAVQqjLLxbcawrLd6WlqUx5m8wJyNRtWPjnkm",
#         "transaction_type": "special",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Food and Drink",
#             "Restaurants",
#             "Fast Food"
#         ],
#         "category_id": "13005032",
#         "date": "2020-01-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "KFC",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "DapWBLqqMPCdXGDm7LQ4inkwDajqd8CvaAXeo",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     },
#     {
#         "account_id": "N1mdPBNNGotBndelVDqbuK8Z68KVD9FW5l7q1",
#         "account_owner": null,
#         "amount": 500,
#         "authorized_date": null,
#         "category": [
#             "Shops",
#             "Sporting Goods"
#         ],
#         "category_id": "19046000",
#         "date": "2020-01-25",
#         "iso_currency_code": "USD",
#         "location": {
#             "address": null,
#             "city": null,
#             "country": null,
#             "lat": null,
#             "lon": null,
#             "postal_code": null,
#             "region": null,
#             "store_number": null
#         },
#         "name": "Madison Bicycle Shop",
#         "payment_channel": "in store",
#         "payment_meta": {
#             "by_order_of": null,
#             "payee": null,
#             "payer": null,
#             "payment_method": null,
#             "payment_processor": null,
#             "ppd_id": null,
#             "reason": null,
#             "reference_number": null
#         },
#         "pending": false,
#         "pending_transaction_id": null,
#         "transaction_code": null,
#         "transaction_id": "XnqMreGGaysQVoj4Pg1GUnRWJVq7K5Cdn7xgQ",
#         "transaction_type": "place",
#         "unofficial_currency_code": null
#     }
# ]

# %% [markdown]
# # 2. Print the categories for each transaction

# %%
# YOUR CODE HERE
transactions = transactions_response['transactions']
categories = []
for t in transactions:
    category = t['category'][0]
    categories.append(category)
categories
# Out:
# ['Payment',
#  'Travel',
#  'Transfer',
#  'Transfer',
#  'Recreation',
#  'Travel',
#  'Food and Drink',
#  'Food and Drink',
#  'Food and Drink',
#  'Transfer',
#  'Travel',
#  'Travel',
#  'Food and Drink',
#  'Payment',
#  'Food and Drink',
#  'Shops',
#  'Payment',
#  'Travel',
#  'Transfer',
#  'Transfer',
#  'Recreation',
#  'Travel',
#  'Food and Drink',
#  'Food and Drink',
#  'Food and Drink',
#  'Transfer',
#  'Travel',
#  'Travel',
#  'Food and Drink',
#  'Payment',
#  'Food and Drink',
#  'Shops',
#  'Payment',
#  'Travel',
#  'Transfer',
#  'Transfer',
#  'Recreation',
#  'Travel',
#  'Food and Drink',
#  'Food and Drink',
#  'Food and Drink',
#  'Transfer',
#  'Travel',
#  'Travel',
#  'Food and Drink',
#  'Payment',
#  'Food and Drink',
#  'Shops']

# %% [markdown]
# ### 3. Create a new DataFrame using the following fields from the JSON transaction data: date, name, amount, category.
#
# (For categories with more than one label, just use the first category label in the list)

# %%
# YOUR CODE HERE

dates = []
names = []
amounts = []

    
for t in transactions:
    
    dates.append(t['date'])
    amounts.append(t['amount'])
    names.append(t['name'])

print(dates, names, amounts)
# Out:
# ['2020-04-15', '2020-04-15', '2020-04-14', '2020-04-14', '2020-04-13', '2020-04-13', '2020-04-12', '2020-04-12', '2020-04-11', '2020-04-10', '2020-03-31', '2020-03-29', '2020-03-26', '2020-03-25', '2020-03-25', '2020-03-25', '2020-03-16', '2020-03-16', '2020-03-15', '2020-03-15', '2020-03-14', '2020-03-14', '2020-03-13', '2020-03-13', '2020-03-12', '2020-03-11', '2020-03-01', '2020-02-28', '2020-02-25', '2020-02-24', '2020-02-24', '2020-02-24', '2020-02-15', '2020-02-15', '2020-02-14', '2020-02-14', '2020-02-13', '2020-02-13', '2020-02-12', '2020-02-12', '2020-02-11', '2020-02-10', '2020-01-31', '2020-01-29', '2020-01-26', '2020-01-25', '2020-01-25', '2020-01-25'] ['CREDIT CARD 3333 PAYMENT *//', 'Uber', 'ACH Electronic CreditGUSTO PAY 123456', 'CD DEPOSIT .INITIAL.', 'Touchstone Climbing', 'United Airlines', "McDonald's", 'Starbucks', 'SparkFun', 'INTRST PYMNT', 'United Airlines', 'Uber', 'Tectra Inc', 'AUTOMATIC PAYMENT - THANK', 'KFC', 'Madison Bicycle Shop', 'CREDIT CARD 3333 PAYMENT *//', 'Uber', 'ACH Electronic CreditGUSTO PAY 123456', 'CD DEPOSIT .INITIAL.', 'Touchstone Climbing', 'United Airlines', "McDonald's", 'Starbucks', 'SparkFun', 'INTRST PYMNT', 'United Airlines', 'Uber', 'Tectra Inc', 'AUTOMATIC PAYMENT - THANK', 'KFC', 'Madison Bicycle Shop', 'CREDIT CARD 3333 PAYMENT *//', 'Uber', 'ACH Electronic CreditGUSTO PAY 123456', 'CD DEPOSIT .INITIAL.', 'Touchstone Climbing', 'United Airlines', "McDonald's", 'Starbucks', 'SparkFun', 'INTRST PYMNT', 'United Airlines', 'Uber', 'Tectra Inc', 'AUTOMATIC PAYMENT - THANK', 'KFC', 'Madison Bicycle Shop'] [25, 5.4, 5850, 1000, 78.5, -500, 12, 4.33, 89.4, -4.22, 500, 6.33, 500, 2078.5, 500, 500, 25, 5.4, 5850, 1000, 78.5, -500, 12, 4.33, 89.4, -4.22, 500, 6.33, 500, 2078.5, 500, 500, 25, 5.4, 5850, 1000, 78.5, -500, 12, 4.33, 89.4, -4.22, 500, 6.33, 500, 2078.5, 500, 500]

# %% [markdown]
# ### 4. Convert the data types to the appropriate types
#
# (i.e. datetimeindex for the date and float for the amount)

# %%
# YOUR CODE HERE
df = pd.DataFrame()
df['dates'] = dates
df['categories'] = categories
df['names'] = names
df['amounts'] = amounts

# %%
df['dates'] = pd.to_datetime(df['dates'], format='%d%m%y', errors='ignore')
pd.DatetimeIndex(df['dates'])
df.index = pd.DatetimeIndex(df['dates'])
df['amounts'] = df['amounts'].astype('float')

# %%
df.drop(columns='dates', inplace=True)
df.head()
# Out:
#             categories                                  names  amounts
# dates
# 2020-04-15     Payment           CREDIT CARD 3333 PAYMENT *//     25.0
# 2020-04-15      Travel                                   Uber      5.4
# 2020-04-14    Transfer  ACH Electronic CreditGUSTO PAY 123456   5850.0
# 2020-04-14    Transfer                   CD DEPOSIT .INITIAL.   1000.0
# 2020-04-13  Recreation                    Touchstone Climbing     78.5

# %% [markdown]
# ---

# %% [markdown]
# # Income Analysis with Plaid
#
# In this section, you will use the Plaid Sandbox to complete the following:
# 1. Determine the previous year's gross income and print the results
# 2. Determine the current monthly income and print the results
# 3. Determine the projected yearly income and print the results

# %%
client.Income.get(access_token)

income_data = client.Income.get(access_token)

gross_inc = income_data['income']['last_year_income_before_tax']
month_inc = income_data['income']['income_streams'][0]['monthly_income']
proj_inc = income_data['income']['projected_yearly_income']

print(f" The previous year's gross income was ${gross_inc:,}. " )
print(f" The current month's income is ${month_inc:,}. " )
print(f" The projected net income for next year is ${proj_inc:,}. " )
# Out:
#  The previous year's gross income was $7,285.
#  The current month's income is $500.
#  The projected net income for next year is $6,085.

# %% [markdown]
# # Budget Analysis
# In this section, you will use the transactions DataFrame to analyze the customer's budget
#
# 1. Calculate the total spending per category and print the results (Hint: groupby or count transactions per category)
# 2. Generate a bar chart with the number of transactions for each category
# 3. Calculate the expenses per month
# 4. Plot the total expenses per month

# %% [markdown]
# ### Calculate the expenses per category

# %%
category_expenses = df.groupby('categories')['amounts'].sum()
category_expenses
#instructions said to count number of transactions but for $amounts that didn't make sense. That's why I used
#the sum() function instead of the count function
# Out:
# categories
# Food and Drink     3317.19
# Payment            6310.50
# Recreation          235.50
# Shops              1500.00
# Transfer          20537.34
# Travel               35.19
# Name: amounts, dtype: float64

# %%
category_expenses.plot.bar(rot=45, title="Expense Breakdown in $")

# %%
category_expenses.plot.pie(rot=45, title="Expense Breakdown in $")

# %% [markdown]
# ### Calculate the expenses per month

# %%
trim_df = df.groupby('dates')['amounts'].sum()

expenses_month = trim_df.groupby(trim_df.index.month).sum()

# %%
expenses_month.plot.bar(rot=360, title="Total Monthly Expenses")
